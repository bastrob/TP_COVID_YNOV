# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
data_conf_1 = pd.read_csv("../input/datacov2/tweets_conf_1.csv")
data_conf_1.head()
# Out:
#               tweet_id                 date           location lang  \
# 0  1242813166012293120  2020-03-25 13:58:43                NaN   fr
# 1  1242810902178664452  2020-03-25 13:49:44              Paris   fr
# 2  1240063153809043456  2020-03-17 23:51:09              paris   fr
# 3  1240224794215415811  2020-03-18 10:33:27  Marseille, France   fr
# 4  1240369603391389696  2020-03-18 20:08:53                NaN   en
#
#                                                 text   emoji  \
# 0  gauche yoda 1mois 1 an l'esprit contradiction ...     NaN
# 1  visioconférence teams télétravail allez maquil...     NaN
# 2  chercheurs australiens réussi eradiquer 100 vi...     NaN
# 3  scandaleux ministre croire français qu'il trai...      📽😱
# 4                                  great police work  👏🏼👏🏼👏🏼
#
#                                               hastag
# 0                                   confinementjour1
# 1                  confinementjour1 confinementjour9
# ...

# %%
data_conf_2 = pd.read_csv("/kaggle/input/datacov2/tweets_conf_2.csv")
data_conf_2.head()
# Out:
#               tweet_id                            date           location  \
# 0  1327922660056162304  Sun Nov 15 10:33:28 +0000 2020                NaN
# 1  1327899139586232322  Sun Nov 15 09:00:00 +0000 2020      France, Paris
# 2  1327922660441993216  Sun Nov 15 10:33:28 +0000 2020                NaN
# 3  1327922661310296064  Sun Nov 15 10:33:28 +0000 2020  beyoncé's kitchen
# 4  1324629606792646662  Fri Nov 06 08:28:03 +0000 2020         Luxembourg
#
#   bounding_box lang                                               text emoji  \
# 0        empty   fr               rt jour n’arrêtera rue redevient rue   NaN
# 1        empty   fr  boulangerie 100m dois-je remplir attestation o...   ❓🥖📄
# 2        empty   fr                        tendance lutte inégalités …     👆
# 3        empty   fr                      rt croyez passer sérieusement   NaN
# 4        empty   fr  — — crise constitué véritable accélérateur  fo...   NaN
#
#                                        hastag
# ...

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
text_conf_1 = data_conf_1['text'].astype(str).tolist()

# Create show_wordcloud method:
def show_wordcloud(data, title):
    text_conf_1 = ' '.join(data_conf_1['text'].astype(str).tolist())
    #print (type(text))
           
# Create the wordcloud object
    fig_wordcloud = WordCloud(background_color='lightgrey',
                            colormap='viridis', width=800, height=600).generate(text_conf_1)
    
# Display the generated image:
    plt.figure(figsize=(10,7), frameon=True)
    plt.imshow(fig_wordcloud)
    plt.axis('off')
    plt.title(title, fontsize=20)
    plt.show()
          
show_wordcloud(data_conf_1,"Nuage de mot du 1er confinement")

# Save the image in the img folder:
#wordcloud.to_file("img/first_review.png")

# %%
# WordCloud for 2nd confinement
text_conf_2 = data_conf_2['text'].astype(str).tolist()

def show_wordcloud_2(data, title):
    text_conf_2 = ' '.join(data_conf_2['text'].astype(str).tolist()) 
    
    fig_wordcloud_2 = WordCloud(background_color='lightgrey',
                            colormap='viridis', width=800, height=600).generate(text_conf_2)
    
    plt.figure(figsize=(10,7), frameon=True)
    plt.imshow(fig_wordcloud_2)
    plt.axis('off')
    plt.title(title, fontsize=20)
    plt.show()  
    
show_wordcloud_2(data_conf_2,"Nuage de mot du 2er confinement")
